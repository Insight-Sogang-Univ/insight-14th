# %% [markdown]
# ## <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> 시계열 데이터 </span>
# ![image.png](attachment:image.png)
# > 순차적인 시간의 흐름에 따라 수집된 데이터
#
# `과거 데이터가 미래에 어떤 영향을 미치는가?`
#
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 종단면 데이터와 횡단면 데이터</span>
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 종단면 데이터 </span>
# > 동일 개체에 대해 특정 시간 간격으로 수집된 데이터
#
# - 시간 의존성 o
# - 개체 또는 단위의 변화 추적
# - 개체 또는 단위의 패턴 및 동향 분석
# - 개체 또는 단위의 효과 및 원인 분석
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 횡단면 데이터 </span>
# > 몇 가지 주제에 대해 특정 시점에서 수집된 데이터
#
# - 시간 의존성 x
# - 다중 변수
# - 개체 또는 단위 간의 비교 분석
# - 변수 간 상관관계 분석
#
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 단변량 시계열과 다변량 시계열 </span>
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 단변량 시계열 </span>
# > 시간에 따라 연속적으로 측정된 **단일 변수**로 이루어진 시계열 데이터
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 다변량 시계열 </span>
# > 같은 시간에 기록된 둘 이상의 변수로 이루어진 시계열 데이터

# %% [markdown]
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 시계열 데이터의 특징 </span>
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 시간의존성 </span>
# > 시간에 따라 변화, 과거 값이 현재에 영향을 미침
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 계절성과 추세 </span>
# ![image.png](attachment:image.png)
# > 시간에 따라 장기적으로 증감 추세, 일정 주기로 반복 패턴
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 자기상관성 </span>
# > 자기자신끼리 상관관계를 가짐 -> 시간이 지남에 따라 값들 간 일정한 패턴과 반복 존재
#
# *so...* 회귀 분석 불가능
# -> 정상성 확인 및 추세 제거 필요

# %% [markdown]
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 시계열 데이터의 분석 요인 </span>
# ![image-5.png](attachment:image-5.png)
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 추세 요인 </span>
# ![image.png](attachment:image.png)
# > 시간에 따라 증감
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 계절 요인 </span>
# ![image-2.png](attachment:image-2.png)
# > 일정한 주기로 반복되는 패턴
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 순환 요인 </span>
# ![image-3.png](attachment:image-3.png)
# > 계절성보다 더 길고 불규칙한 주기로 반복되는 변동
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 불규칙 요인 </span>
# ![image-4.png](attachment:image-4.png)
# > 추세, 계절, 순환성을 모두 제거한 뒤 남은 예측 불가능한 변동

# %% [markdown]
# ## <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> 시계열 데이터 전처리 </span>
# ![image.png](attachment:image.png)
#
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 결측치 처리</span>
# > 삭제, 단순 대치, 보간, 머신러닝 기법 등 존재
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 보간법 </span>
# > 주어진 데이터 포인트의 값을 사용하여 두 개 이상의 데이터 포인트 사이에서 누락된 값을 추정하는 수학적 기법
#
# ex)
#
# ```python
# 시간: 1   2   3   4   5
# 값:  10  NaN  NaN  40  50
# ```
# 비슷한 비율로 변화했겠지~ -> 중간 값 채움
#
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 이상치 탐지</span>
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> IQR </span>
# ![image-2.png](attachment:image-2.png)
# > 주기성 없거나 비교적 안정적인 구간 값에서 사용
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> Z-score </span>
# $Z=(x−μ)/σ$
#
# > 계절성/추세가 약하거나 값 변동폭 일정한 시계열에서 효과적
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> STL 분해 </span>
# ![image-3.png](attachment:image-3.png)
# > 계절성/추세 뚜렷한 시계열에 적합
#
# - 모델
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> CART </span>
# ![image-4.png](attachment:image-4.png)
# > 예측 오차가 일정 임계값 이상인 지점을 이상치로 간주
#
# - 비선형 관계 잘 포착
# - 다변량에도 사용 가능
#
# *but...*
# - 노이즈가 많은 데이터에서는 과적합 위험
# - 트리 깊이에 따라 탐지 민감도 달라짐
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 클러스터링 기반 </span>
# > 정상 구간에 데이터는 특정 클러스터에 잘 모이는 원리 사용
#
# >시계열의 특징(feature)을 추출한 후, 각 시점(또는 구간)을 벡터로 표현해 클러스터링 수행
#
# - 데이터 복잡/다변량에 유용
#
# *but...*
# - 하이퍼파라미터에 민감
# - 시계열의 순서 정보 미반영
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 오토 인코더 </span>

# %% [markdown]
# ![image.png](attachment:image.png)
# > 인공신경망 기반, 정상 데이터에 대한 특징을 학습하고, 학습된 모델에 데이터를 입력했을 때 재구성한 결과와 학습된 정상 특징과의 차이점을 비교하여 이상 여부 판단
#
# - 복잡한 비선형/다변량 학습 및 탐지 가능
#
# *but...*
# - 학습 데이터 많아야 함
# - 모델 해석 어렵

# %% [markdown]
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 평활화</span>
# ![image.png](attachment:image.png)
# > 시계열 데이터에서 노이즈를 줄이고, 전체적인 흐름이나 추세를  더 명확하게 파악하기 위해 데이터를 부드럽게 만드는 기술
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;">이동 평균</span>
# ![image-2.png](attachment:image-2.png)
#
# $N = \text{Moving Window의 길이}$
#
# ![image-3.png](attachment:image-3.png)
#
# > 시계열의 부분 집합으로 평균을 구하여 평활화 효과 얻는 방법
#
# | 종류 | 설명 | 사용 |
# | --- | --- | --- |
# | 단순 이동평균 (SMA) | 단순히 기간 내 모든 값 평균 | 변동이 심하지 않고 비교적 안정적인 시계열 |
# | 가중 이동평균(WMA) | 최근 값에 더 큰 가중치 부여 | 최근 데이터가 더 중요한 상황 |
# | 지수 이동평균(EMA) | 최근 데이터에 지수적으로 더 많은 가중치 부여  | 최근 값에 매우 빠르게 반응해야 하는 시계열   ex) 주식 |

# %% [markdown]
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 요소 분해 </span>
# ![image.png](attachment:image.png)
# > 주어진 시계열 데이터를 개별 성분(추세성, 계절성, 순환성, 불규칙성)으로 분해하는 과정
#
#
# $Y_t$ = $f$( $T_t, S_t, C_t, R_t$)
#
# - $T_t$ : 추세성분 (시점 t에서의 추세요소)
# - $S_t$ : 계절성분 (시점 t에서의 계절요소)
# - $C_t$ : 순환성분 (시점 t에서의 순환요소)
# - $R_t$ : 불규칙성분 (시점 t에서의 불규칙요소)
# </aside>

# %% [markdown]
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 가법 모형 </span>
# $$
# y_t = T_t + S_t + R_t
# $$
#
# > 시계열 = 추세 + 계절성 + 불규칙성
#
# `각 변동 요인 독립적으로 더해지고, 모든 요소 영향 일정`
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 승법 모형 </span>
#
# $$
# y_t = T_t * S_t * R_t
# $$
#
# > 시계열 = 추세 * 계절성 * 불규칙성
#
# `추세가 커질수록 게절성/불규칙성 효과 비레해서 커짐`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> 정상성 </span>
# >  시계열 데이터가 평균, 분산 등의 통계적 특성이 시간에 따라 일정한 수준으로 유지되는 것

# %% [markdown]
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 강한 정상성 </span>
# ![image.png](attachment:image.png)
# > 강정상성을 띠는 시계열은 모든 적률(평균, 분산, 왜도, 첨도)이 시간과 무관하게 일정
# -> 비현실적...
#
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 약한 정상성 </span>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - 단위근의 시계열적 의미
#     - 단위근 검정
#     - 확정적 추세와 확률적 추세
#     - 정상성 확보 방법
#
#     ## <span style="background-color:#E0F7FA; color:#1565C0; padding:4px; border-radius:5px;"> 잠재 요인 </span>
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 수행 방식</span>
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> SVC: 특이값 분해 </span>
# `관측된 평점을 가장 잘 재현하는 적절한 잠재 요인의 개수 k 찾기`

# %% [markdown]
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 정상성 판단: 단위근 검정 </span>
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 단위근 </span>
# > 어떤 양의 정수 n에 대해 아래 방정식의 근이 되는 복소수
#
# 시계열 모델의 특성방정식에서 근이 1인 경우, 해당 시계열은 단위근을 가짐 -> `비정상 시계열`
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 검정 방법 </span>
#
# ##### 1. ADF(Augmented Dicky-Fuller) 검정
#
# > **단위근(Unit root)** 존재 여부를 통해 시계열의 정상성 판단
#
# - **귀무가설(H₀):** ‘시계열에 단위근이 존재한다**’ → 비정상 시계열**
# - **대립가설(H₁):** ‘시계열에 단위근이 존재하지 않는다’ **→ 정상 시계열**
#
# ##### 2. KPSS(Kwiatkowski-Phillips-Schmidt-Shin) 검정**
#
# > **단위근 기반**의 검정이지만 **귀무가설이 반대**
#
# - **귀무가설(H₀):** ‘시계열에 단위근이 존재하지 않는다’ **→ 정상 시계열**
# - **대립가설(H₁):** ‘시계열에 단위근이 존재한다**’ → 비정상 시계열**

# %% [markdown]
# ### <span style="background-color:#FFFFE0; color:#CD5C5C; padding:4px; border-radius:5px;"> 정상성 확보 방법 </span>
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;">추세 제거 </span>
# > 시계열 데이터에서 한 시점의 값과 그 이전 시점의 값을 차분하여 변화량을 계산
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 계절성 제거 </span>
#
# > $$
# y_t^* = y_t - y_{t - m}
# $$
#
# ##### <span style="background-color:#DCDCDC; color:#000000; padding:4px; border-radius:5px;"> 분산 안정화 </span>
# > 로그 변환 혹은 박스-콕스 변환 사용
