# %% [markdown]
# ### **시계열1** ###

# %% [markdown]
# #### **시계열 데이터란?** ####

# %% [markdown]
# - 순차적인 시간의 흐름에 따라 수집된 데이터
# - 연속한 관측치는 서로 상관관계가 존재하며, 순서가 중요한 “시퀀스 데이터”로 간주됨
# - 단순 시간-수치로 이루어진 데이터 뿐만 아니라, 단어의 순서가 중요한 NLP 데이터에도 동일한 개념이 적용될 수 있음

# %% [markdown]
# #### **종단면 데이터와 횡단면 데이터** ####

# %% [markdown]
# ![image.png](attachment:850fe8fd-ae19-4387-b1f1-27869682d833.png)

# %% [markdown]
# ### **종단면(시계열) 데이터** ###

# %% [markdown]
# : 동일한 개체에 대해 특정 시간 간격으로 수집된 데이터

# %% [markdown]
# **종단면데이터의 특징**
# 1. 시간 의존성
# 2. 개체 또는 단위 추적
# 3. 패턴 및 동향 분석
# 4. 효과 및 원인 분석

# %% [markdown]
# ### **횡단면(비시계열) 데이터** ###

# %% [markdown]
# : 몇 가지 주제에 대해 특정 시점에서 수집된 데이터

# %% [markdown]
# **횡단면데이터의 특징**
# 1. 시간 의존성
# 2. 다중 변수
# 3. 비교 분석
# 4. 상관관계 분석

# %% [markdown]
# ### **단변량 시계열과 다변량 시계열** ###

# %% [markdown]
# 1. **단변량 시계열(Univariate Time Series) :**
# - 시간에 따라 연속적으로 측정된 단일 변수로 이루어진 시계열 데이터
# - 시간의 흐름에 따른 패턴과 트렌드 이해

# %% [markdown]
# 2. **다변량 시계열(Univariate Time Series) :**
# - 같은 시간에 기록된 **둘 이상의 변수**로 이루어진 시계열 데이터
# - 변수 간 상호 작용 및 영향력 파악

# %% [markdown]
# ### **시계열 데이터의 특성** ###

# %% [markdown]
# 1. 시간 의존성 (시계열 데이터는 시간에 따라 변화함)
# -  시계열 데이터는 시간 순서에 따라 관측되므로 데이터의 순서를 바꾸면 의미가 달라짐
# - 과거의 값이 현재의 값에 영향 미침
# - 시점 간의 상관관계를 고려해야 함

# %% [markdown]
# 2. 계절성과 추세
# - 계절성: 일정 주기에 따라 반복적으로 나타나는 데이터의 변동( 패턴 고려한 모델링 가능)
# - 추세 : 시간흐름에 따른 장기적인 증가/감소 영향

# %% [markdown]
# 3. 자기상관성(이전 시점의 값이 이후 시점의 값에 영향을 미친다)
# <br>: 자기자신끼리 상관관계를 갖는 특성을 의미
# - 한 시점의 값이 과거의 값과 통계적으로 관련 있는 성질
# - 즉, 시간이 지남에 따라 값들 간에 일정한 패턴이나 반복이 존재한다는 것
# - 관측값들은 서로 독립적이지 않다

# %% [markdown]
# **자기상관성 때문에 회귀분석이 불가능함**
# 1. 통계적 추론의 제약 및 오류
# 2. 예측의 어려움 & 모델 복잡성 증가

# %% [markdown]
# ### **시계열 데이터의 분석요인** ###

# %% [markdown]
# 1. 추세요인
# - 시간에 따라 지속적으로 증가 or 감소
# - 꾸준히 증가하거나 감소하는 선형 그래프

# %% [markdown]
# 2. 계절요인
# - 일정 주기로 패턴 반복
# - 시간적 표현: 주기적인 변동을 나타내는 그래프

# %% [markdown]
# 3. 순환 요인
# - 계절성보다 더 길고 불규칙한 주기로 반복되는 변동
# - 시간적 표현: 길게 상승과 하강을 반복하는 파형 그래프

# %% [markdown]
# 4. 불규칙 요인
# - 추세, 계절성, 순환성을 모두 제거한 뒤 남은 예측 불가능한 변동
# - 노이즈, 우연적 사건, 일시적인 변동, 이상치 등을 모두 포함
# - 시각적 표현: 불규칙한 변동을 나타내는 그래프

# %% [markdown]
# ![image.png](attachment:704670f9-e2e4-4034-b2d9-05c7e0bdd7ec.png)

# %% [markdown]
# ### **시계열 데이터 전처리** ###

# %% [markdown]
# ### 전처리 프로세스
#
# 1. 데이터 확인/시각화
# 2. 결측치 확인 → 결측치 처리(삭제/단순 대치/보간/이동평균 대치 등)
# 3. 이상치 탐지 → 이상치 처리(삭제/단순 대치/보간/이동평균 대치 등)
# 4. 요소 분해

# %% [markdown]
# **결측값 처리**
# 1. 보간법
#    - 사라진 값(결측값, NaN)을  합리적으로 메워주는 과정
#    - 결측치/이상치 구간이 짧거나 신호의 패턴이 단순한 경우에 보간 정확도 높음

# %% [markdown]
# **이상치 탐지 및  처리**
# 1. IQR Rule-based Anomaly Detection
#    - 장점 : 단순하고 해석이 명확, 빠름(통계기반)
#    - 단점 : 추세나 계절성이 강한 시계열에는 부적합, 분포가 비정상적(non-stationary)일 경우 오탐률이 높음
#
# 2. Z-score
# - 장점 : 계산이 간단하고 빠름, 해석 직관적
# - 단점 : 정규분포 가정에 민감, 안정적 threshold 설정이 어려움
#
# 3. STL 분해
# - 장점 : 진짜 "이상한 값"만 잡아낼 수 있음
# - 단점 : 계산 비용이 크고 매우 긴 시계열에는 파라미터 튜닝이 필요함

# %% [markdown]
# **평활화**

# %% [markdown]
# ![image.png](attachment:3fea06e8-b7f8-49f7-ab70-e716a5c85d72.png)

# %% [markdown]
# : 시계열 데이터에서 노이즈를 줄이고, 전체적인 흐름이나 추세를  더 명확하게 파악하기 위해 데이터를 부드럽게 만드는 기술

# %% [markdown]
# **이동평균**

# %% [markdown]
# ![image.png](attachment:5a8fdd36-0338-4961-b692-46c0d9c258f9.png)

# %% [markdown]
# 사용목적
# - 노이즈 제거: 일시적인 급등/급락을 평탄화
# - 추세 파악: 상승/하강 흐름을 쉽게 식별
# - 예측의 기초자료: 시계열 예측(ARIMA 등)의 기반이 되기도 함

# %% [markdown]
# - 이동평균의 유형
#
# | 종류 | 설명 | 사용 |
# | --- | --- | --- |
# | 단순 이동평균 (SMA) | 단순히 기간 내 모든 값 평균 | 변동이 심하지 않고 비교적 안정적인 시계열 |
# | 가중 이동평균(WMA) | 최근 값에 더 큰 가중치 부여 | 최근 데이터가 더 중요한 상황 |
# | 지수 이동평균(EMA) | 최근 데이터에 지수적으로 더 많은 가중치 부여  | 최근 값에 매우 빠르게 반응해야 하는 시계열   ex) 주식 |

# %% [markdown]
# ### **요소분해** ###

# %% [markdown]
# ![image.png](attachment:943153d0-ee44-4f5b-a393-195224c7f75b.png)

# %% [markdown]
# : 주어진 시계열 데이터를 개별 성분(추세성, 계절성, 순환성, 불규칙성)으로 분해하는 과정

# %% [markdown]
# **가법모형**
# - 시계열 = 추세 + 계절성 + 불규칙성
# - 시계열 관측값은 변동요인들의 가법(+)으로 설명될 수 있다 가정
# - **각 변동 요인들이 독립적으로 더해지며, 모든 요소의 영향이 일정함**
# - 시계열 전체에서 계절성의 진폭이 일정할 때 적합하다

# %% [markdown]
# **승법모형**
# - 시계열 = 추세 x 계절성 x 불규칙성
# - 시계열 관측값은 변동요인들의 승법(*)으로 설명될 수 있다 가정
# - **추세가 커질수록 계절성이나 불규칙성의 효과도 비례해서 커짐**
# - 진폭이 시간에 따라 달라질 때에 적합하다

# %% [markdown]
# ### **정상성** ###

# %% [markdown]
# : 시계열 데이터가 평균, 분산 등의 통계적 특성이 시간에 따라 일정한 수준으로 유지되는 것.
# <br>:정상성을 띠는 시계열 데이터-> **정상 시계열(Stationary Time Series)**,
#
# 정상성을 띠지 않는 시계열 데이터-> 비정상 시계열(Non-stationary Time Serie)

# %% [markdown]
# **강한 정상성과 약한 정상성**

# %% [markdown]
# 1. 강한 정상성은 실제 데이터에선 거의 없음
# 2. 약한 정상성
# - 평균은 모든 시점에 대해 일정하다
# - 분산은 모든 시점에 대해 일정하다
# - 공분산은 시점에 의존하지 않고, 단지 시차에만 의존한다

# %% [markdown]
# **정상성을 검즘할 때는 단위근 검정**
#
# : 수학적 의미는 생략^^
# - '단위근'이란 이름은 '단위(1)' + '근(방정식의 해)'을 합친 말
# - **시계열 모델의 특성방정식에서 근이 1인 경우**, 해당 시계열은 **단위근을 가짐**
#
#     → 이는 **비정상 시계열**을 의미함

# %% [markdown]
# 단위근 검정의 대표 방법
# 1. ADF 검정
#
# 2.  KPSS 검정

# %% [markdown]
# **KPSS vs ADF: 검정 방향이 반대인 두 방법, 언제 결과가 다를까?**
#
# 확정적 추세(Deterministic Trend)가 존재하는 경우
#
# → **KPSS와 ADF 검정의 결론이 서로 다르게 나올 수 있음**

# %% [markdown]
# ![image.png](attachment:b00eb9ca-e687-4315-83a9-07a883dd556a.png)

# %% [markdown]
# - **확정적 추세**: 추세가 완벽하게 예측 가능하고 일정하게 존재
#     - 예) $X_t=0.05t+\epsilon_t$
#     - 잡음으로 약간의 흔들림은 있지만, 시간에 따라 일정한 방향 (선형적으로 증가) 으로 움직임.
#
# .
#
# - **확률적 추세**: 추세선 자체가 시간에 따라 이동함 (랜덤 워크 성격)
#     - 예) $X_t=X_{t-1}+\epsilon_t$
#     - 단위근(랜덤 워크)과정으로, 시간에 따라 우연히 위아래로 이동하며 영구적인 충격이 누적됨

# %% [markdown]
# ### **정상성 확보를 위한 여러가지 방법들** ###

# %% [markdown]
# 1. 추세제거
# - 시계열이 지속적으로 증가하거나 감소할 때 적용
# 2. 계절성 제거
# - 시계열이 주기적인 패턴을 가질 때 적용
# 3. 분산 안정화
# - 시계열의 변동 폭이 점점 커지거나 작아질 때 적용
