# %% [markdown]
# # 👍 **데이터로 보는 비즈니스 상황 사전 과제**

# %% [markdown]
# ### <span style="color:purple"> <strong> 1. Data-Driven Decision Making <strong> </span>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> DDDM란? <strong>
# </span>

# %% [markdown]
# : 개인의 직관, 경험이 아닌 실제 데이터를 통해 얻은 객관적 증가와 인사이트를 바탕으로 조직의 전략적 결정을 내리는 과정! 이는 데이터 참고 이상의 가치가 있으며, 의사결정 과정의 중심에 데이터를 두는 접근 방식.

# %% [markdown]
# ```
# - 사실 기반 접근
# - 객관성 확보
# - 패턴 및 트렌드 발견: 여기서 상관관계를 파악하여 미래를 예측하거나 기회 포착

# %% [markdown]
# 최근에는 AI와 ML 기술이 발전하며 DDDM의 중요성이 커지는 추세. 특히 AI를 통해 방대한 양의 데이터를 실시간으로 처리하고, 인간이 파악하기 어려운 복잡한 인사이트를 제공함으로써 정교한 의사결정이 가능해지고 있다.

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> DDDM이 중요한 이유<strong>
# </span>

# %% [markdown]
# 1. 의사결정의 정확성 및 신뢰성 향상
# 2. 새로운 기회 및 잠재적 리스크 식별
# 3. 운영 효율성 증대 + 비용 감소
# 4. 고객에 대한 경험 개선
# 5. 지속적인 개선과 혁신 문화의 조성

# %% [markdown]
# ```
# 결론적으로, 불확실한 비즈니스 환경 속에서 현명+빠른+전략적인 선택을 내릴 수 있게 하는 나침반과 같은 존재!

# %% [markdown]
# ### <span style="color:purple"> <strong> 2. 6 Steps of DDDM<strong> </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 1단계. 목표 및 문제 정의<strong>
# </span>

# %% [markdown]
# : 모든 데이터 분석의 시작은 명확한 목표 설정에서 비롯됨!
# - 좋은 질문: "지난 분기 대비 이탈률이 20% 증가한 핵심 원인은 무엇인가?", "어떤 마케팅 채널이 가장 높은 고객 생애 가치(LTV)를 보이는 고객을 유입시키는가?"
# - 나쁜 질문: "어떻게 하면 매출이 늘어날까?" (너무 광범위!!!)

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 2단계. 관련 데이터 수집<strong>
# </span>

# %% [markdown]
# : 정의된 문제에 답을 줄 수 있는 데이터를 식별 및 수집하는 단계!
# - 내부 데이터
#   - 고객 관계 관리(CRM) 시스템: 고객 정보, 구매 내역
#   - 웹/앱 로그 데이터: 페이지뷰, 클릭, 체류 시간
#   - 재무 데이터: 매출, 비용, 이익
#   - 운영 데이터: 재고, 생산량
# - 외부 데이터
#   - 시장 조사 보고서: 경쟁사 분석, 산업 동향 분석
#   - 정부 및 공공 데이터: 인구 통계, 경제 지표
#   - 소셜 미디어 데이터: 브랜드 언급, 고객 반응 등

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 3단계. 데이터 정제<strong>
# </span>

# %% [markdown]
# : 수집된 데이터는 RAW DATA 형태이기 때문에 결측값, 오류, 중복 데이터 등을 정제해 주어야 함.
# - 결측값 처리
# - 이상치 탐지 및 처리
# - 데이터 형식 변환
# - 데이터 통합

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 4단계. 데이터 분석 및 탐색<strong>
# </span>

# %% [markdown]
# : 준비된 데이터에서 패턴, 관계, 특이점을 찾아내는 단계임. 여기서 데이터 시각화를 주로 사용하고, 차트/그래프/맵 등 시각적 요소를 통해 복잡한 데이터를 한눈에 파악하게 함.
# - 기초 통계량 확인 (평균, 중앙값, 표준편차 등)
# - 데이터 분포 시각화 (히스토그램, 박스플롯)
# - 변수 간 상관관계 분석 (산점도, 히트맵)
# - 다양한 관점으로 데이터를 분할하여 비교 (지역별, 연령대별 매출 비교 etc)

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 5단계. INSIGHT 도출<strong>
# </span>

# %% [markdown]
# : 분석 결과를 해석하여 비즈니스 문제에 대한 답을 찾고 구체적인 해결 방안을 도출하는 단계임.

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 6단계. 실행 및 모니터링<strong>
# </span>

# %% [markdown]
# : 도출된 인사이트를 바탕으로 실제 비즈니스 액션을 실행하고 그 결과를 지속적으로 모니터링함

# %% [markdown]
# ### <span style="color:purple"> <strong> 3. 데이터 분석의 유형<strong> </span>

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 1. 기술적 분석(=설명 분석): 무슨 일이 일어난 거임?<strong>
# </span>

# %% [markdown]
# - 목표: 과거 데이터의 요약, 패턴 파악
# - 주요 기법: 기초 통계, 데이터 시각화 (대시보드, 보고서)
# - 비즈니스 질문 예시
#   - 지난 분기 총 매출액은?
#   - 가장 많이 팔린 제품은?
#   - 일일 활성 사용자 수는 몇 명?
# - 활용 사례: 웹사이트 트래픽 리포트, 월간 매출 보고서, kpi

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 2. 진단적 분석: 왜 일어난 거임?<strong>
# </span>

# %% [markdown]
# - 목표: 현상의 원인 규명, 상관/인과관계 파악
# - 주요 기법: 드릴 다운, 데이터 마이닝, 상관관계 분석
# - 비즈니스 질문 예시
#   - 왜 특정 지역에서 매출이 급감했지?
#   - 왜 특정 마케팅 캠페인의 전환율이 유독 낮았지?
# - 활용 사례: 특정 지역의 배송 지연 원인을 파악하기 위해 배송 단계별 데이터를 상세히 분석하는 경우, 특정 마케팅 활동이 구매 전환에 미친 영향을 분석하는 경우

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 3. 예측적 분석: 무슨 일이 일어날까?<strong>
# </span>

# %% [markdown]
# - 목표: 미래 결과 예측, 트렌드 전망
# - 주요 기법: 회귀 분석, 시계열 분석, 머신러닝 모델
# - 비즈니스 질문 예시
#   - 다음 분기 예상 매출액은 얼마지?
#   - 어떤 고객이 다음 달에 이탈하려나?
#   - 내일 특정 제품의 수요는 얼마나 될까?
# - 활용 사례: 고객 이탈 예측 모델, 수요 예측을 통한 재고 관리, 신용 점수 평가를 통한 대출 심사

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 4. 처방적 분석: 그럼 이제 뭘 해야 하지?<strong>
# </span>

# %% [markdown]
# - 목표: 최적의 의사결정 제안, 행동 방침 추천
# - 주요 기법: 최적화 알고리즘, 시뮬레이션, A/B 테스팅
# - 비즈니스 질문 예시
#   - 고객 이탈을 막기 위해 어떤 할인 쿠폰을 제공해야 할까?
#   - 한정된 마케팅 예산을 각 채널에 어떻게 배분해야 최대의 ROI를 얻을 수 있을까?
# - 활용 사례: 항공사의 동적 가격 책정, 구글맵의 실시간 최적 경로 추천, 개인화된 상품 추천 시스템

# %% [markdown]
# ### <span style="color:purple"> <strong> 4 .지표<strong> </span>

# %% [markdown]
# ```
# 지표는 비즈니스의 성과, 프로세스, 시스템 등을 정량적으로 측정하고 평가하기 위한 수치적 기준!

# %% [markdown]
# 지표가 없다면 목표 달성 여부를 판단할 수 없으며, 비즈니스의 건강 상태를 진단하거나 문제점을 개선하기도 어렵다. 잘 설계된 지표는 조직 구성원들이 같은 목표를 향해 나아가도록 방향을 제시하고, 성과에 대한 객관적인 평가 기준을 제공한다!!!!

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> 좋은 지표의 조건<strong>
# </span>

# %% [markdown]
# - 구체성: 무엇을 측정하는지 명확하고 구체적이어야
# - 측정 가능성: 정량적으로 측정이 가능해야
# - 달성 가능성: 현실적으로 달성 가능해야
# - 관련성 비즈니스 목표와 직접적으로 연결되어야
# - 시간 기반: 목표 달성 기한이 명확해야

# %% [markdown]
# <STRONG> 또한, 허무 지표와 실행 가능 지표를 구분하는 것이 중요하다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 허무 지표: 앱 총 다운로드 수, 웹사이트 누적 가입자 수 등. 수치 자체는 좋아 보이지만, 실제 비즈니스 성과와 직접적인 관련이 적고 의사결정에 도움을 주지 못하는 지표
# - 실행 가능 지표: 월간 활성 사용자 수(MAU), 전환율, 고객 이탈률 등. 비즈니스의 현 상태를 명확히 보여주고, 이 지표를 개선하기 위한 구체적인 행동을 유도할 수 있는 지표

# %% [markdown]
# <span style="color:black; background-color:#E6E6FA; padding:2px 4px; border-radius:4px">
# <strong> AARRR 프레임워크 활용하기<strong>
# </span>

# %% [markdown]
# ```
# AARRR 프레임워크 = 해적 지표 라고도 불린다.

# %% [markdown]
# <strong> 1단계. Acquisition (획득) : 사용자는 우리 서비스를 어떻게 발견하고 방문하는가?

# %% [markdown]
# - 사용자가 어떤 경로(채널)를 통해 우리 웹사이트나 앱에 처음으로 들어오게 되는지를 측정하는 단계
# - 핵심 질문: 어떤 채널이 가장 효과적인가? 채널별 고객 획득 비용은 얼마인가?
# - 주요 지표: 채널별 신규 방문자 수, 앱 다운로드 수, 광고 클릭률, 검색 엔진 최적화 등

# %% [markdown]
# <strong> 2단계. Activation (활성화) : 방문한 사용자가 우리의 핵심 가치를 처음으로 경험했는가?

# %% [markdown]
# - 단순 방문을 넘어, 사용자가 회원가입 / 핵심 기능 사용 등 의미 있는 첫 경험을 느끼게 하는 단계
# - 핵심 질문: 사용자들이 가입 절차를 성공적으로 마치는가? 첫 방문 경험에 만족하는가?
# - 주요 지표: 회원가입 전환율, 무료 체험 신청률, 특정 핵심 기능 사용률, 첫 방문 시 체류 시간 및 페이지 뷰

# %% [markdown]
# <strong> 3단계. Retention (유지) : 서비스를 경험한 사용자가 만족하여 다시 돌아오는가?

# %% [markdown]
# - 사용자가 일회성 방문에 그치지 않고 꾸준히 재방문하여 서비스를 지속적으로 이용하는지 측정하는 단계. (스타트업의 장기적 성공에 가장 중요한 단계임!)
# - 핵심 질문: 얼마나 많은 사용자가 재방문하는가? 사용자들은 얼마나 자주 방문하는가?
# - 주요 지표: 재방문율, 이탈률, 방문 주기, 일/주/월간 활성 사용자 수

# %% [markdown]
# <strong> 4단계. Referral (추천) : 사용자가 만족하여 주변에 자발적으로 입소문을 내는가?

# %% [markdown]
# - 기존 고객이 새로운 고객을 데려오는 성장을 측정하는 단계
# - 핵심 질문: 사용자들이 서비스를 공유하는가? 친구 초대 프로그램이 효과적인가?
# - 주요 지표: 순추천지수, 바이럴 계수, 친구 초대 기능 사용률, 소셜 미디어 공유 수

# %% [markdown]
# <strong> 5단계. Revenue (매출) : 어떻게 수익을 창출하고 있는가?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 사용자의 활동이 실질적인 매출로 어떻게 연결되는지 분석하는 단계
# - 핵심 질문: 유료 전환율을 얼마인가? 고객 1인당 평균 매출은 얼마인가?
# - 주요 지표: 유료 고객 전환율, 고객 생애 가치, 객단가, 월간 반복 매출
