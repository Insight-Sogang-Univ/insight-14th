# %% [markdown]
# # 1. 판다스 라이브러리 사용하기

# %% [markdown]
# ### 1-1) 직접 import를 사용해서 pandas를 실행해보세요 (약자를 pd로 설정해주세요)

# %% [markdown]
# #### - 판다스 실행하기

# %%
import pandas as pd

# %% [markdown]
# ### 1-2) 실습 파일을 불러와 'df'라는 이름으로 데이터프레임을 만들어주세요

# %% [markdown]
# #### - 'insight 중고차 정보.csv' 파일 불러오기

# %%
df = pd.********('./insight 중고차 정보.csv')

# %%
#데이터프레임 확인하기
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  김민지
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아
# 3   c1  340.0   19.0  coupe  서울  문건우
# 4   c2    NaN    NaN  coupe  수원  노승혁
# 5   v2    NaN   29.0    suv  광주  류한결
# 6   s3  490.0   26.0  sedan  고양  이종현
# 7   v3  400.0    NaN    suv  광주  김일호

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:7e67470b-dfd5-4177-878a-577492b4ae28.png)

# %% [markdown]
# # 2. 직접 데이터프레임 만들어보기

# %% [markdown]
# ### 2-1) 사용할 리스트 만들기

# %%
customer_id = ['s1', 's2', 'v1', 'c1', 'c2', 'v2', 's3', 'v3']
total_km = [400, 480, 465, 340, None, None, 490, 400]
fuel = [25, 24, 24, 19, None, 29, 26, None]
car = ['sedan', 'sedan', 'suv', 'coupe', 'coupe', 'suv', 'sedan', 'suv']
local = ['수원', '서울', '화성', '서울', '수원', '광주', '고양', '광주']
owner = ['김민지', '김재성', '문선아', '문건우', '노승혁', '류한결', '이종현', '김일호']

# %% [markdown]
# ### 2-2) data 딕셔너리를 사용해서 df에 데이터프레임 생성하기

# %%
data={
    #['고객ID', '주행거리', '연료사용량', '차종', '지역', '차주']를 컬럼 이름으로 딕셔너리 구성
    '고객ID' : customer_id, '주행거리' : total_km, '연료사용량' : fuel, '차종' : car, '지역' : local, '차주' : owner
}

columns= [] #생략 가능 

df = pd.*********(data)

# %%
#데이터프레임 확인하기
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  김민지
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아
# 3   c1  340.0   19.0  coupe  서울  문건우
# 4   c2    NaN    NaN  coupe  수원  노승혁
# 5   v2    NaN   29.0    suv  광주  류한결
# 6   s3  490.0   26.0  sedan  고양  이종현
# 7   v3  400.0    NaN    suv  광주  김일호

# %% [markdown]
# 처음 불러온 데이터프레임과 같은 형태라면 정답입니다!

# %% [markdown]
# # 3. 데이터 확인하기

# %% [markdown]
# ### 3-1) 데이터프레임의 기본 정보를 확인해주세요

# %% [markdown]
# #### 1. head를 사용하여 앞에서 3번째 값까지 확인

# %%
df.****(3)
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  김민지
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:0d6feae6-8637-49a4-9fc4-ce3b2740632c.png)

# %% [markdown]
# #### 2. tail을 사용하여 마지막에서 4번째 값까지 확인

# %%
df.****(4)
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 4   c2    NaN    NaN  coupe  수원  노승혁
# 5   v2    NaN   29.0    suv  광주  류한결
# 6   s3  490.0   26.0  sedan  고양  이종현
# 7   v3  400.0    NaN    suv  광주  김일호

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d908857d-3db7-4a8b-98be-209b81564de3.png)

# %% [markdown]
# #### 3. shape를 사용해 기본적 형태 확인

# %%
df.*****
# Out:
# (8, 6)

# %% [markdown]
# 정답 : (8, 6)

# %% [markdown]
# #### 4. info를 사용하여 컬럼 별 특성 확인

# %%
df.****()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고객ID    8 non-null      object
#  1   주행거리    6 non-null      float64
#  2   연료사용량   6 non-null      float64
#  3   차종      8 non-null      object
#  4   지역      8 non-null      object
#  5   차주      8 non-null      object
# dtypes: float64(2), object(4)
# memory usage: 516.0+ bytes

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:2d780640-c9ed-457c-b3f3-f70763d4de54.png)

# %% [markdown]
# #### 5. describe를 사용하여 기초 통계값을 확인하기

# %%
df.********()
# Out:
#              주행거리      연료사용량
# count    6.000000   6.000000
# mean   429.166667  24.500000
# std     58.687023   3.271085
# min    340.000000  19.000000
# 25%    400.000000  24.000000
# 50%    432.500000  24.500000
# 75%    476.250000  25.750000
# max    490.000000  29.000000

# %% [markdown]
# ![image.png](attachment:d70d4c0c-e357-4e7c-8466-de40a4de9986.png)

# %% [markdown]
# #### 6. isnull을 사용하여 컬럼 별로 결측치 확인

# %%
df.******()
# Out:
#     고객ID   주행거리  연료사용량     차종     지역     차주
# 0  False  False  False  False  False  False
# 1  False  False  False  False  False  False
# 2  False  False  False  False  False  False
# 3  False  False  False  False  False  False
# 4  False   True   True  False  False  False
# 5  False   True  False  False  False  False
# 6  False  False  False  False  False  False
# 7  False  False   True  False  False  False

# %% [markdown]
# 아래 그림처럼 나오면 됩니다. (True값이 결측치임을 의미합니다.)
#
# ![image.png](attachment:f3b85c3d-a074-429f-a4ed-c22631b0fb9b.png)

# %% [markdown]
# #### 7. dtypes를 사용해 데이터타입을 확인하기

# %%
df.******
# Out:
# 고객ID      object
# 주행거리     float64
# 연료사용량    float64
# 차종        object
# 지역        object
# 차주        object
# dtype: object

# %% [markdown]
# ![image.png](attachment:018d6e6f-9855-49d2-a47c-2a243ecfb767.png)

# %% [markdown]
# #### 8. count를 통해 결측치를 제외한 데이터의 행 수를 반환하기

# %%
df.*****()
# Out:
# 고객ID     8
# 주행거리     6
# 연료사용량    6
# 차종       8
# 지역       8
# 차주       8
# dtype: int64

# %% [markdown]
# ![image.png](attachment:b2c8200d-abf8-4489-bb09-1ebeeef434f2.png)

# %% [markdown]
# #### 9. value_counts를 사용하여 지역 열의 데이터 종류 및 개수 확인

# %%
df['지역'].************()
# Out:
# 지역
# 수원    2
# 서울    2
# 광주    2
# 화성    1
# 고양    1
# Name: count, dtype: int64

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:b44cfc34-a1db-4612-911e-b36c902192a5.png)

# %% [markdown]
# # 4. 데이터 추출하기

# %% [markdown]
# ### 4-1) 다양한 인덱싱 방법을 사용해 요구하는 데이터를 반환해주세요

# %% [markdown]
# #### 1. 컬럼명을 사용하여 6번째 차주를 반환

# %%
df[***][***]
# Out:
# '류한결'

# %% [markdown]
# '류한결'이 나오면 정답!

# %% [markdown]
# #### 2. 컬럼 명을 사용하여 4번째 차종을 반환

# %%
df[***][***]
# Out:
# 'coupe'

# %% [markdown]
# 'coupe'가 나오면 정답!

# %% [markdown]
# #### 3. loc를 사용하여 3번 인덱스의 차종 반환

# %%
df.***[***, ***]
# Out:
# 'coupe'

# %% [markdown]
# 'coupe'가 나오면 정답!

# %% [markdown]
# #### 4. loc를 사용하여 2번 인덱스의 지역 반환

# %%
df.***[***, ***]
# Out:
# '화성'

# %% [markdown]
# '화성'이 나오면 정답!

# %% [markdown]
# #### 5. iloc를 사용하여 5번째 고객ID 반환

# %%
df.****[***, ***]
# Out:
# 'c2'

# %% [markdown]
# 'c2'가 나오면 정답!

# %% [markdown]
# #### 6. iloc를 사용하여 5번째 차주 반환

# %%
df.****[***, ***]
# Out:
# '노승혁'

# %% [markdown]
# '노승혁'이 나오면 정답!

# %% [markdown]
# #### 7. iloc을 사용하여 마지막 행 반환 (Series 타입으로 출력)

# %%
df.****[***]
# Out:
# 고객ID        v3
# 주행거리     400.0
# 연료사용량      NaN
# 차종         suv
# 지역          광주
# 차주         김일호
# Name: 7, dtype: object

# %% [markdown]
# 아래 그림과 같이 나오면 됩니다.
#
# ![image.png](attachment:fdc290f6-bf13-41d5-bea6-f8466fa3b507.png)

# %% [markdown]
# #### 8. 차주 컬럼을 반환 (Series 타입으로 출력)

# %%
df[***]
# Out:
# 0    김민지
# 1    김재성
# 2    문선아
# 3    문건우
# 4    노승혁
# 5    류한결
# 6    이종현
# 7    김일호
# Name: 차주, dtype: object

# %% [markdown]
# 아래 그림과 같이 나오면 됩니다.
#
# ![image.png](attachment:f9bed3f7-a451-4e4f-a797-ac868c2b3b08.png)

# %% [markdown]
# ### 4-2) 이번엔 슬라이싱을 사용하여 요구하는 데이터를 반환해주세요

# %% [markdown]
# #### 1. 인덱스로 2~4번째 데이터 슬라이싱

# %%
df[***]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아
# 3   c1  340.0   19.0  coupe  서울  문건우

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:79d8936e-b757-48cb-8f47-18304beb195c.png)

# %% [markdown]
# #### 2. loc를 사용하여 차종-차주의 4~7번째 데이터 슬라이싱

# %%
df.***[***, ***]
# Out:
#       차종  지역   차주
# 3  coupe  서울  문건우
# 4  coupe  수원  노승혁
# 5    suv  광주  류한결
# 6  sedan  고양  이종현

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:b26e9a59-c83e-40ec-99a0-b486956df5b1.png)

# %% [markdown]
# #### 3. iloc를 사용하여 차종-차주의 4~7번째 데이터 슬라이싱

# %%
df.****[***, ***]
# Out:
#       차종  지역   차주
# 3  coupe  서울  문건우
# 4  coupe  수원  노승혁
# 5    suv  광주  류한결
# 6  sedan  고양  이종현

# %% [markdown]
# 아래 그림과 같이 나오면 됩니다.
#
# ![image.png](attachment:438d2b4d-d204-4d37-a2c4-abf963374975.png)

# %% [markdown]
# ### 4-3) 불리언 인덱싱을 통해 원하는 데이터를 추출해주세요

# %% [markdown]
# #### 1. 지역이 서울인 행을 모두 반환

# %%
df[***]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 1   s2  480.0   24.0  sedan  서울  김재성
# 3   c1  340.0   19.0  coupe  서울  문건우

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:1058998b-27d8-469f-a20f-edc6bcdd6687.png)

# %% [markdown]
# #### 2. 주행거리가 400 이상인 행을 모두 반환

# %%
df[***]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  김민지
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아
# 6   s3  490.0   26.0  sedan  고양  이종현
# 7   v3  400.0    NaN    suv  광주  김일호

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:713526fc-778a-4e85-b123-f279a4c4bef8.png)

# %% [markdown]
# #### 3. 지역이 서울이고, 주행거리가 400 이상인 행을 반환

# %%
df[***]
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 1   s2  480.0   24.0  sedan  서울  김재성

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:0fc019cd-bf57-4905-8fe4-ebd85c2e093c.png)

# %% [markdown]
# ### 4-4) 인덱스를 여러 방식으로 재설정해주세요

# %% [markdown]
# #### 1. reindex를 사용하여 인덱스가 8부터 시작하는 내림차순 df2 생성

# %%
df2 = df.*******([7,6,5,4,3,2,1,0]) # range 함수를 사용해서 list(range(8,-1,-1)) 로 작성해도 됩니다.

# %%
# 데이터프레임 확인
df2
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 7   v3  400.0    NaN    suv  광주  김일호
# 6   s3  490.0   26.0  sedan  고양  이종현
# 5   v2    NaN   29.0    suv  광주  류한결
# 4   c2    NaN    NaN  coupe  수원  노승혁
# 3   c1  340.0   19.0  coupe  서울  문건우
# 2   v1  465.0   24.0    suv  화성  문선아
# 1   s2  480.0   24.0  sedan  서울  김재성
# 0   s1  400.0   25.0  sedan  수원  김민지

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:0f10fac2-c169-434a-8299-fa558c6fd967.png)

# %% [markdown]
# #### 2. df2를 다시 0부터 시작하는 오름차순 인덱스로 돌려놓되, 값들이 인덱스를 따라가지 않도록 주의 (Hint : .index = )

# %%
df2.***** = list(range(0,8))

# %%
# 데이터프레임 확인
df2
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   v3  400.0    NaN    suv  광주  김일호
# 1   s3  490.0   26.0  sedan  고양  이종현
# 2   v2    NaN   29.0    suv  광주  류한결
# 3   c2    NaN    NaN  coupe  수원  노승혁
# 4   c1  340.0   19.0  coupe  서울  문건우
# 5   v1  465.0   24.0    suv  화성  문선아
# 6   s2  480.0   24.0  sedan  서울  김재성
# 7   s1  400.0   25.0  sedan  수원  김민지

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:cf01d5ad-ea0f-4df2-8fda-2cef708ff15d.png)

# %% [markdown]
# #### 3. set_index를 사용해서 df로부터 고객ID를 인덱스로 하는 df3 생성

# %%
df3 = df.*********('고객ID')

# %%
# 데이터프레임 확인
df3
# Out:
#        주행거리  연료사용량     차종  지역   차주
# 고객ID
# s1    400.0   25.0  sedan  수원  김민지
# s2    480.0   24.0  sedan  서울  김재성
# v1    465.0   24.0    suv  화성  문선아
# c1    340.0   19.0  coupe  서울  문건우
# c2      NaN    NaN  coupe  수원  노승혁
# v2      NaN   29.0    suv  광주  류한결
# s3    490.0   26.0  sedan  고양  이종현
# v3    400.0    NaN    suv  광주  김일호

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:7dce180a-2f08-42d4-8894-1b04f36690b4.png)

# %% [markdown]
# # 5. 데이터 조작하기

# %% [markdown]
# ### 5-1) 데이터를 추가하고 삭제해주세요

# %% [markdown]
# #### 1. 연비를 나타내는 '연비' 컬럼 추가 (계산식 : 주행거리 / 연료사용량)

# %%
# 연비 = 주행거리/연료사용량
df[***]=

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주         연비
# 0   s1  400.0   25.0  sedan  수원  김민지  16.000000
# 1   s2  480.0   24.0  sedan  서울  김재성  20.000000
# 2   v1  465.0   24.0    suv  화성  문선아  19.375000
# 3   c1  340.0   19.0  coupe  서울  문건우  17.894737
# 4   c2    NaN    NaN  coupe  수원  노승혁        NaN
# 5   v2    NaN   29.0    suv  광주  류한결        NaN
# 6   s3  490.0   26.0  sedan  고양  이종현  18.846154
# 7   v3  400.0    NaN    suv  광주  김일호        NaN

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:96fdd361-8e05-41f1-8f55-2ea762de6f8e.png)

# %% [markdown]
# #### 2. drop을 사용하여 연료사용량 컬럼을 삭제

# %%
# axis=1, inplace=True 로 설정해주세요
df.****('연료사용량', axis=*, inplace=****)

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 0   s1  400.0  sedan  수원  김민지  16.000000
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 2   v1  465.0    suv  화성  문선아  19.375000
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 4   c2    NaN  coupe  수원  노승혁        NaN
# 5   v2    NaN    suv  광주  류한결        NaN
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 7   v3  400.0    suv  광주  김일호        NaN

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:d9a2f84b-5d58-43b1-a98a-6fcfe8ef9b37.png)

# %% [markdown]
# ### 5-2) 데이터를 정렬해주세요

# %% [markdown]
# #### 1. 연비 값을 기준으로 내림차순으로 데이터프레임 정렬하기

# %%
# sort_values를 사용, ascending=False, inplace=True 로 설정
df.***(by = '연비', ascending = ***, inplace = ****)

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 2   v1  465.0    suv  화성  문선아  19.375000
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 0   s1  400.0  sedan  수원  김민지  16.000000
# 4   c2    0.0  coupe  수원  노승혁        NaN
# 5   v2    0.0    suv  광주  류한결        NaN
# 7   v3  400.0    suv  광주  김일호        NaN

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:53559385-4a77-44ac-8f56-5ca0999cedd8.png)

# %% [markdown]
# #### 2. 인덱스를 기준으로 내림차순 정렬하기

# %%
df.***(ascending = ***) # 원본 df에는 수정이 일어나지 않도록 해주세요!
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 7   v3  400.0    suv  광주  김일호        NaN
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 5   v2    0.0    suv  광주  류한결        NaN
# 4   c2    0.0  coupe  수원  노승혁        NaN
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 2   v1  465.0    suv  화성  문선아  19.375000
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 0   s1  400.0  sedan  수원  김민지  16.000000

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:a82426ff-ab98-4bca-b7e4-fa4e5a577896.png)

# %% [markdown]
# ### 5-3) 데이터 변환

# %% [markdown]
# #### 1. 주행거리 컬럼의 Nan 데이터를 0으로 변환하기

# %%
# fillna(0) 를 사용하여 주행거리의 Nan 값을 0으로 채워주세요 
df['주행거리'] = df['주행거리'].***(0)

# %%
# 데이터프레임 확인
df
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 0   s1  400.0  sedan  수원  김민지  16.000000
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 2   v1  465.0    suv  화성  문선아  19.375000
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 4   c2    0.0  coupe  수원  노승혁        NaN
# 5   v2    0.0    suv  광주  류한결        NaN
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 7   v3  400.0    suv  광주  김일호        NaN

# %% [markdown]
# 이렇게 나오면 성공!
#
# ![image.png](attachment:9ed3de63-976f-4c24-a111-6c246b8bd7d4.png)

# %% [markdown]
# #### 2. 고객ID 컬럼의 타입을 확인하고 범주형 변수로 바꿔주기

# %%
# dtypes를 사용해서 주행거리 컬럼의 타입을 확인해주세요
df.***
# Out:
# 고객ID     object
# 주행거리    float64
# 차종       object
# 지역       object
# 차주       object
# 연비      float64
# dtype: object

# %%
# astype 을 사용해서 str로 바꿔주세요
df['주행거리'] = df['주행거리'].***('str')

# %%
# 데이터 타입 재확인
df.dtypes
# Out:
# 고객ID     object
# 주행거리     object
# 차종       object
# 지역       object
# 차주       object
# 연비      float64
# dtype: object

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:ee39830a-d610-483a-b2c9-5df7b6c4934f.png)

# %% [markdown]
# #### 3. 데이터 값 바꿔보기

# %%
df #데이터프레임 확인
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  김민지
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아
# 3   c1  340.0   19.0  coupe  서울  문건우
# 4   c2    NaN    NaN  coupe  수원  노승혁
# 5   v2    NaN   29.0    suv  광주  류한결
# 6   s3  490.0   26.0  sedan  고양  이종현
# 7   v3  400.0    NaN    suv  광주  김일호

# %% [markdown]
# replace()를 활용해 김일호를 윤해민으로 바꿔봅시다!

# %%
df.***('김일호', '윤해민')
# Out:
#   고객ID   주행거리  연료사용량     차종  지역   차주
# 0   s1  400.0   25.0  sedan  수원  김민지
# 1   s2  480.0   24.0  sedan  서울  김재성
# 2   v1  465.0   24.0    suv  화성  문선아
# 3   c1  340.0   19.0  coupe  서울  문건우
# 4   c2    NaN    NaN  coupe  수원  노승혁
# 5   v2    NaN   29.0    suv  광주  류한결
# 6   s3  490.0   26.0  sedan  고양  이종현
# 7   v3  400.0    NaN    suv  광주  윤해민

# %% [markdown]
# 이렇게 나오면 성공!
#
# ![image.png](attachment:84340c65-06ab-4a0e-b9b4-84bee45e0f12.png)

# %% [markdown]
# #### 4. 전치를 통해 데이터프레임을 바꿔봐요

# %%
df.***() #함수를 사용해보세요
# Out:
#            0      1      2      3      4     5      6      7
# 고객ID      s1     s2     v1     c1     c2    v2     s3     v3
# 주행거리   400.0  480.0  465.0  340.0    NaN   NaN  490.0  400.0
# 연료사용량   25.0   24.0   24.0   19.0    NaN  29.0   26.0    NaN
# 차종     sedan  sedan    suv  coupe  coupe   suv  sedan    suv
# 지역        수원     서울     화성     서울     수원    광주     고양     광주
# 차주       김민지    김재성    문선아    문건우    노승혁   류한결    이종현    김일호

# %% [markdown]
# 이렇게 나오면 성공!
#
# ![image.png](attachment:1985dfe3-ff2e-43e0-ba20-c2cabb8460da.png)

# %%
df.* #메서드를 사용하세요
# Out:
#            0      1      2      3      4     5      6      7
# 고객ID      s1     s2     v1     c1     c2    v2     s3     v3
# 주행거리   400.0  480.0  465.0  340.0    NaN   NaN  490.0  400.0
# 연료사용량   25.0   24.0   24.0   19.0    NaN  29.0   26.0    NaN
# 차종     sedan  sedan    suv  coupe  coupe   suv  sedan    suv
# 지역        수원     서울     화성     서울     수원    광주     고양     광주
# 차주       김민지    김재성    문선아    문건우    노승혁   류한결    이종현    김일호

# %% [markdown]
# ![image.png](attachment:40d298e4-36cf-4d53-aa69-b9e895e56040.png)

# %% [markdown]
# ### 5-4) 데이터프레임을 합쳐주세요

# %% [markdown]
# #### 1. 형태가 동일한 추가 데이터를 기존 데이터프레임과 합친 df4 만들기

# %%
# 추가 데이터

new_customer_id = ['n1', 'n2', 'n3']
new_total_km = [300, 410, 280]
new_car = ['coupe', 'coupe', 'sedan']
new_local = ['서울', '부산', '서울']
new_owner = ['윤해민', '김윤서', '황종빈']
efficiency = [17, 20.5, 19.87]

new_data={'고객ID': new_customer_id,
      '주행거리': new_total_km,
      '차종': new_car,
      '지역': new_local,
      '차주': new_owner,
        '연비': efficiency
}

columns = ['고객ID', '주행거리', '차종', '지역', '차주', '연비']


new_df = pd.DataFrame(new_data, columns=columns)
new_df
# Out:
#   고객ID  주행거리     차종  지역   차주     연비
# 0   n1   300  coupe  서울  윤해민  17.00
# 1   n2   410  coupe  부산  김윤서  20.50
# 2   n3   280  sedan  서울  황종빈  19.87

# %%
# concat 을 사용해서 df4 만들기 (밑으로 (행방향으로) 이어붙여주세요!)
df4 = pd.***([df, new_df])

# %%
# 데이터프레임 확인
df4
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 2   v1  465.0    suv  화성  문선아  19.375000
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 0   s1  400.0  sedan  수원  김민지  16.000000
# 4   c2    0.0  coupe  수원  노승혁        NaN
# 5   v2    0.0    suv  광주  류한결        NaN
# 7   v3  400.0    suv  광주  김일호        NaN
# 0   n1    300  coupe  서울  윤해민  17.000000
# 1   n2    410  coupe  부산  김윤서  20.500000
# 2   n3    280  sedan  서울  황종빈  19.870000

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:a66bbac2-4182-4be3-aadb-0daa073a13ca.png)

# %% [markdown]
# #### 2. 형태가 다른 데이터프레임을 합쳐 df5 만들기

# %%
# 추가 데이터

new2_customer_id = ['n5', 'n6', 'n7']
new2_car = ['sedan', 'coupe', 'suv']
new2_owner = ['김찬우', '김현서', '이지현']
new2_efficiency = [17.76, 21, 19.5]
color = ['red', 'green', 'blue']


new_data2={'고객ID': new2_customer_id,
      '차종': new2_car,
      '차주': new2_owner,
          '연비': new2_efficiency,
           '도색': color
}

columns = ['고객ID', '차종', '차주', '연비', '도색']


new2_df = pd.DataFrame(new_data2, columns=columns)

new2_df
# Out:
#   고객ID     차종   차주     연비     도색
# 0   n5  sedan  김찬우  17.76    red
# 1   n6  coupe  김현서  21.00  green
# 2   n7    suv  이지현  19.50   blue

# %%
# merge를 사용해서 df5 만들기, how=outer 설정

df5 = pd.***(df, new2_df, how = 'outer', on = ['고객ID','차종','차주','연비'])

# %%
# 데이터프레임 확인

df5
# Out:
#    고객ID   주행거리     차종   지역   차주         연비     도색
# 0    c1  340.0  coupe   서울  문건우  17.894737    NaN
# 1    c2    0.0  coupe   수원  노승혁        NaN    NaN
# 2    n5    NaN  sedan  NaN  김찬우  17.760000    red
# 3    n6    NaN  coupe  NaN  김현서  21.000000  green
# 4    n7    NaN    suv  NaN  이지현  19.500000   blue
# 5    s1  400.0  sedan   수원  김민지  16.000000    NaN
# 6    s2  480.0  sedan   서울  김재성  20.000000    NaN
# 7    s3  490.0  sedan   고양  이종현  18.846154    NaN
# 8    v1  465.0    suv   화성  문선아  19.375000    NaN
# 9    v2    0.0    suv   광주  류한결        NaN    NaN
# 10   v3  400.0    suv   광주  김일호        NaN    NaN

# %% [markdown]
# 아래 그림이 나오면 됩니다.
#
# ![image.png](attachment:d9fb19dc-347e-4234-b454-471b60d1febd.png)

# %% [markdown]
# # 6. 집계함수 연산

# %% [markdown]
# ### 6-1) 다양한 연산메소드를 사용하여 다음의 문제를 해결해주세요

# %% [markdown]
# #### 1. 연비의 평균 구하기

# %%
# mean 메소드 사용
df['연비'].***()
# Out:
# 18.423178137651824

# %% [markdown]
# 정답: 18.423178137651824

# %% [markdown]
# #### 2. 연비의 중앙값 구하기

# %%
# median 메소드 사용
df['연비'].***()
# Out:
# 18.846153846153847

# %% [markdown]
# 정답: 18.846153846153847

# %% [markdown]
# #### 3. 연비의 최대값과 최소값 구하기

# %%
# max, min 사용

print('연비최대값:', df['연비'].***() , '연비최소값:', df['연비'].***())
# Out:
# 연비최대값: 20.0 연비최소값: 16.0

# %% [markdown]
# 연비최대값: 20.0 연비최소값: 16.0

# %% [markdown]
# ### 6-2) groupby 메소드를 사용하여 문제를 해결해주세요

# %% [markdown]
# #### 1. 차종 별 연비의 평균 확인하기

# %%
# groupby 와 mean 메소드를 사용해주세요
df.
# Out:
# 차종
# coupe    17.894737
# sedan    18.282051
# suv      19.375000
# Name: 연비, dtype: float64

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:95573728-bdf6-438a-ab36-84b61596bee9.png)

# %% [markdown]
# #### 2. 지역 별로 차주는 누가 있는지 확인하기

# %%
# groupby 와 unique 메소드를 사용해주세요
df.
# Out:
# 지역
# 고양         [이종현]
# 광주    [류한결, 김일호]
# 서울    [김재성, 문건우]
# 수원    [김민지, 노승혁]
# 화성         [문선아]
# Name: 차주, dtype: object

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
#
# ![image.png](attachment:bf117e27-841d-479f-a6c1-17e6d078239b.png)

# %% [markdown]
# #### 3. 지역 별로 차종 별 개수 확인하기

# %%
# groupby 와 value_counts 메소드를 사용해주세요
df.
# Out:
# 지역  차종
# 고양  sedan    1
# 광주  suv      2
# 서울  coupe    1
#     sedan    1
# 수원  coupe    1
#     sedan    1
# 화성  suv      1
# Name: count, dtype: int64

# %% [markdown]
# 이렇게 나오면 정답입니다!!
#
# ![image.png](attachment:6e8758ae-129b-4d09-99f7-32dc40f7a1f6.png)

# %% [markdown]
# 실습 진행하시느라 고생 많았습니다!! ^^

# %% [markdown]
# ### +) 심심하신 분들을 위한 추가 문제

# %%
df
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 2   v1  465.0    suv  화성  문선아  19.375000
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 0   s1  400.0  sedan  수원  김민지  16.000000
# 4   c2    0.0  coupe  수원  노승혁        NaN
# 5   v2    0.0    suv  광주  류한결        NaN
# 7   v3  400.0    suv  광주  김일호        NaN

# %% [markdown]
# #### 0. df를 인덱스 기준으로 정렬합니다.

# %%
df = df.
df
# Out:
#   고객ID   주행거리     차종  지역   차주         연비
# 0   s1  400.0  sedan  수원  김민지  16.000000
# 1   s2  480.0  sedan  서울  김재성  20.000000
# 2   v1  465.0    suv  화성  문선아  19.375000
# 3   c1  340.0  coupe  서울  문건우  17.894737
# 4   c2    0.0  coupe  수원  노승혁        NaN
# 5   v2    0.0    suv  광주  류한결        NaN
# 6   s3  490.0  sedan  고양  이종현  18.846154
# 7   v3  400.0    suv  광주  김일호        NaN

# %% [markdown]
# #### 1. 세번째, 첫번째, 여섯번째, 다섯번째의 데이터를 추출해 데이터프레임의 형태로 dfdf에 저장하는 한줄코드를 작성해주세요!

# %%
dfdf = df.

# %%
# 데이터프레임 확인
dfdf
# Out:
#   고객ID   주행거리     차종  지역   차주      연비
# 2   v1  465.0    suv  화성  문선아  19.375
# 0   s1  400.0  sedan  수원  김민지  16.000
# 5   v2    0.0    suv  광주  류한결     NaN
# 4   c2    0.0  coupe  수원  노승혁     NaN

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
# ![image.png](attachment:0593e287-77c7-4c70-98aa-70e3cb215e79.png)

# %% [markdown]
# #### 2. dfdf 원본의 인덱스를 초기화시키는 한줄코드를 작성해주세요! (컬럼이 새로 생성되지 않도록 주의해주세요)

# %%
dfdf.

# %%
# 데이터프레임 확인
dfdf
# Out:
#   고객ID   주행거리     차종  지역   차주      연비
# 0   v1  465.0    suv  화성  문선아  19.375
# 1   s1  400.0  sedan  수원  김민지  16.000
# 2   v2    0.0    suv  광주  류한결     NaN
# 3   c2    0.0  coupe  수원  노승혁     NaN

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
# ![image.png](attachment:73135043-7e8c-432b-929f-a899c0cb793a.png)

# %% [markdown]
# #### 3. loc 방식을 사용하여 dfdf의 행에 대해 주행거리와 연비를 더한 값을 Series의 형태로 반환해주세요! (만약 error가 발생한다면, 데이터의 타입을 확인하고 적절하게 변경해주세요!)

# %%
dfdf.
dfdf.
# Out:
# 0    484.375
# 1      416.0
# 2        0.0
# 3        0.0
# dtype: object

# %% [markdown]
# 아래 그림처럼 나오면 됩니다.
# ![image.png](attachment:74a1ea86-ea62-4ac5-bbc9-9ca57bcc6523.png)

# %% [markdown]
# # 수고하셨습니다!!
