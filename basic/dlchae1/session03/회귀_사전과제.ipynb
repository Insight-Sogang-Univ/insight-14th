# %% [markdown]
# ## SESSION03_회귀📈

# %% [markdown]
# ### 1. 머신러닝의 종류

# %% [markdown]
# ##### <span style="background-color:#FFF5F7; color:#000000; padding:4px; border-radius:5px;"> 1-1. 지도 학습(Supervised Learning) </span>
# - 정답(label)이 **있는** 데이터
# - 예측값(prediction)을 이미 만들어둔 정답과 같아지도록 기계를 학습시키는 것
# - 문제와 정답을 모두 알려주고 공부시키는 방법
# - ex) 회귀, 분류
# - ex) 수많은 고양이와 기린의 사진 제공 -> 각 사진이 고양이인지 기린인지 정답 제공 => 어떤 사진을 주었을 때 고양이인지 기린인지 판단 가능!

# %% [markdown]
# ##### <span style="background-color:#FFF5F7; color:#000000; padding:4px; border-radius:5px;"> 1-2. 비지도 학습(Umsupervised Learning) </span>
# - 정답(label)이 **없는** 데이터
# - 데이터 속의 **패턴** 또는 각 데이터 간의 **유사도**를 기계가 학습하도록 하는 것
# - 답을 가르쳐주지 않고 공부시키는 방법
# - ex) 군집화
# - ex) 노랗고 얼룩 무늬가 있고 목이 긴 동물 / 그렇지 않은 동물로 구분 => 데이터의 특성을 스스로 파악하여 비슷한 사진끼리 분류

# %% [markdown]
# ##### <span style="background-color:#FFF5F7; color:#000000; padding:4px; border-radius:5px;"> 1-3. 강화 학습(Reinforcement Learning) </span>
# - 시행착오를 반복하여 정답을 찾는 과정
# - 보상 => 상은 최대화!, 벌은 최소화! => 행위를 강화하는 학습
# - ex) 알파고

# %% [markdown]
# ### 2. 회귀와 분류

# %% [markdown]
# ##### <span style="background-color:#FFDDEB; color:#000000; padding:4px; border-radius:5px;"> 2-1. 회귀(Regression)란? </span>
# - 데이터가 **연속형 변수**를 예측하기 위해 사용될 때 ex) 음식 배달 시간 예측
# - 주어진 데이터(X)를 기반으로 정답(Y)를 잘 맞추는 함수
# ![image.png](attachment:image.png)
# ⬆︎ 그래프 상의 파란선을 찾는 것!

# %% [markdown]
# ##### <span style="background-color:#FFDDEB; color:#000000; padding:4px; border-radius:5px;"> 2-2. 분류(Classification)란? </span>
# - 데이터가 **범주형 변수**를 예측하기 위해 사용될 때 ex) 당뇨병 여부 예측
# - 입력된 데이터를 주어진 항목들로 나눔
# 1. 기존 데이터가 어떤 레이블에 속하는지 패턴을 알고리즘으로 인지
# 2. 새롭게 관측된 데이터에 대한 레이블을 판별
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. 선형 회귀

# %% [markdown]
# ##### <span style="background-color:#FFC0CB; color:#000000; padding:4px; border-radius:5px;"> 3-1. 선형 회귀란? </span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 데이터를 가장 잘 설명하는 회귀선을 찾는 과정
# - 현재 데이터 요약 + 아직 관측되지 않은 미래 값을 예측
# - 예측하고자 하는 것 => 종속 변수(y)
# - 예측을 위해 사용하는 변수 => 독립 변수(x)
# - ex) 시간에 따른 주가 예측
# 시간 => 독립 변수(x), 주가 => 종속 변수(y)

# %% [markdown]
# ##### <span style="background-color:#FFC0CB; color:#000000; padding:4px; border-radius:5px;"> 3-2. 단순 선형 회귀 분석 </span>

# %% [markdown]
# ![image.png](attachment:image.png)
# ⬆︎ 단순 -> **하나**의 독립 변수(x)만 존재
# - 데이터를 가장 잘 설명하는 직선 y=ax+b을 찾는 과정
# ㄴ 직선을 결정짓는 적절한 `a: 회귀계수(기울기), b: y절편`를 찾는 과정

# %% [markdown]
# > a, b는 어떻게 찾지?: 잔차(residual)를 정의해나가자!
# - 잔차: `실제값 - 예측값 간의 차이`
# - 회귀선을 잘 찾는 과정: <u>예측값</u>을 조절하며 잔차 줄여나가는 과정

# %% [markdown]
# > #### 최소제곱법(Least Squares Method): 최적의 회귀선 찾는 방식
#
# ![image.png](attachment:image.png)
# ⬆︎ 잔차의 제곱의 합이 최소가 되는 지점 => 최적의 회귀선

# %% [markdown]
# ##### <span style="background-color:#FFC0CB; color:#000000; padding:4px; border-radius:5px;"> 3-3. 경사하강법(Gradient Descent) </span>
# `1. 목적함수(Objective Function)`: 달성하고자 하는 것!
# - 목적: 최적화를 통해 오차 최소화하는 것
#
# `2. 손실함수(Loss Function)`: 개별 데이터 샘플에 대한 오차를 측정하는 함수
# - 예측값 $\hat{y}$와 실제값 $y$의 차이를 계산
# ![image.png](attachment:image.png)
# ⬆︎ $t_i$ : $i$번째 데이터포인트 실제값, $y_i$ : $i$번째 예측값
#
# `3. 비용함수(Cost Function)`: 전체 데이터셋에서 평균적인 손실을 측정하는 함수
# - 손실함수를 모든 데이터 포인트에 대해 계산한 후 평균 or 합산한 값
# - 모델 학습시 대부분 비용함수를 최소화하는 것이 목표! (비용함수 = 목표함수)

# %% [markdown]
# ![image.png](attachment:image.png)
# ⬆ 검정 점: 최솟값, 파란 점에서의 미분값: 그래프의 접선의 기울기
# - 현재 값이 최솟값의 왼쪽: 기울기(미분 값) 음수 => `현재 값 - 미분 값` = > 현재 값이 커짐 => 점이 오른쪽으로 이동
# - 현재 값이 최솟값의 오른쪽: 기울기(미분 값) 양수 => `현재 값 - 미분 값` = > 현재 값이 작아짐 => 점이 왼쪽으로 이동
# - 현재 값이 최솟값에 도달: 미분 값 = 0 => `현재 값 - 미분 값` 변화 X, 멈춤
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# `4. 학습률(α: learning rate)`
# - **얼만큼** 이동? => **적당한** 보폭
# ![image.png](attachment:image.png)
# ⬆
# - Learning Rate가 너무 작다면, 모델이 수렴할 때 까지 너무 오랜 시간 소요
# - Learning Rate가 너무 크다면, 모델이 수렴하지 못하고 발산
#
# - 학습률 설정법
# 1. 초기에 작은 값부터 시도
# 2. 실험을 통해 조정

# %% [markdown]
# `5. Local Minima 문제`
# - 모든 비용함수가 하나의 최솟값을 가지지 않기 때문에 발생
# - 해결법: `모멘텀`: 이전의 기울기, 이동해오던 방향을 고려하도록 관성 부여
# - 기울기에 관성 부여 => 작은 기울기는 쉽게 넘어감
# - 지역 최솟값 탈출

# %% [markdown]
# ##### <span style="background-color:#FFC0CB; color:#000000; padding:4px; border-radius:5px;"> 3-4. 다중 선형 회귀 </span>
# - $y = W_1 x_1 + W_2 x_2 + ... + W_n x_n + b $
# - 데이터를 **두개 이상**의 독립 변수를 사용하여 표현

# %% [markdown]
# ![image.png](attachment:image.png)
# ⬆︎ 독립변수  $x_i$ 2개 => 3차원 공간, 회귀 곡선 = 평면
# 최소제곱법 or 경사하강법 사용, 관측자와 평면간의 차이 => 잔차

# %% [markdown]
# ##### <span style="background-color:#FFC0CB; color:#000000; padding:4px; border-radius:5px;"> 3-5. 다중공선성(Multicollinearity) </span>
# - 변수들이 겹칠 때
# - 회귀 분석에서 독립 변수들 간에 상관관계가 큰 경우

# %% [markdown]
# > ##### 상관계수
# ![image.png](attachment:image.png)
# - 변수간의 통계적 관계, 상관관계의 정도
# - 상관관계(r) -1과 1사이에 존재
# - r이 -1, 1에 가꺼울수록 두 변수의 상관성⬆️
# - r < 0: 음의 상관관계 => 한쪽이 커지면 한쪽 작아짐
# - r > 0: 양의 상관관계 => 한쪽이 커지면 같이 커짐
# - r = 0 선형 상관관계 없음

# %% [markdown]
# > ##### 2. VIF지수 (분산 팽창 인수)
# - 회귀 모델의 결정 계수 R squre을 사용하여 계산
# - VIF 높다 => 다중공선성 존재
# - VIF = 1: 상관관계 X
# - VIF < 5: 다중공선성 문제 X
# - VIF > 5: 다중공선성 징후 가능성 O, 주의!
# - VIF > 10: 다중공선성 심각, 회귀 모델 불안정 가능성⬆️ => 변수 제거 or 조치 필요

# %% [markdown]
# > ##### 3. 다중공선성 대처 방법
# 1. 변수 제거
# 2. 변수 변환
# 3. 규제 선형 모델 활용
# 4. PAC: 상관 있는 변수들을 묶어서 더 적은 수의 대표 축으로 바꾸는 것
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. 규제 선형 모델

# %% [markdown]
# ##### <span style="background-color:#FF69B4; color:#000000; padding:4px; border-radius:5px;"> 4-1. 규제 선형 모델이란? </span>
# - 모델이 학습 데이터에 과적합(overfitting) 되지 않도록 규제를 가하고자 하는 모델
#
# - 선형 회귀 모델에서는 특성에 곱해지는 계수(기울기)의 크기 조정
# - 변수의 개수⬆️ => 모델 복잡 => 과적합 가능성⬆️

# %% [markdown]
# ##### <span style="background-color:#FF69B4; color:#000000; padding:4px; border-radius:5px;"> 4-2. 릿지 회귀(L2 규제) </span>
# - $ \text{Cost Function} = \text{RSS} + \alpha \sum_{j=1}^{p} w_j^2 $
# - 회귀계수의 <u>제곱</u>을 패널티 => 회귀계수가 클수록 강한 패널티
# - 계수 크기 조절 기능
# - WHEN? 예측 변수 많을 때, 다중공선성 존재할 때

# %% [markdown]
# ##### <span style="background-color:#FF69B4; color:#000000; padding:4px; border-radius:5px;"> 라쏘 회귀(L1 규제) </span>
# - $ \text{Cost Function} = \text{RSS} + \alpha \sum_{j=1}^{p} |w_j| $
# - 회귀계수의 <u>절댓값</u>을 패털티 => 회귀계수의 크기와 상관 X
# - 변수 선택 기능
# -  WHEN? 예측 변수 수 많고, 일부만 중요할 때, 모델의 해석을 간단하게 유지하고자 할 때

# %% [markdown]
# ##### <span style="background-color:#FF69B4; color:#000000; padding:4px; border-radius:5px;"> 4-4. 엘라스틱넷 (L1 + L2)  </span>
# - $\text{Cost Function} = \text{RSS} + \alpha_1 \sum_{j=1}^{p} |w_j| + \alpha_2 \sum_{j=1}^{p} w_j^2$
# - 안정적인 예측(모든 변수가 균형 있게 줄어듦)과 희소성(변수 제거)을 동시에 달성
# - WHEN?: 예측 변수 수 많고, 중요한 변수 선택 + 다중공선성 관리할 때

# %% [markdown]
# ### 5. 모델 평가 방법

# %% [markdown]
# ##### <span style="background-color:#FF1493; color:#000000; padding:4px; border-radius:5px;"> 5-1. 성능 평가 지표 </span>

# %% [markdown]
# > ##### 평균 제곱 오차(Mean Squared Error)
#
# - 모델의 예측값과 실제 관측값 사이의 오차 제곱의 평균
# - ${MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$
# - 큰 오차에 민감하게 반응 => 이상치에 민감

# %% [markdown]
# > ##### 평균 절대 오차(Mean Absolute Error)
# - 모델의 예측값과 실제 관측값 사이의 절대값 오차의 평균
# - ${MAE} = \frac{1}{n} \sum_{i=1}^{n} |y_i - \hat{y}_i|^2$
# - 모든 오차 동일
# - 이상치가 존재해도 예측 성능 유지

# %% [markdown]
# ##### <span style="background-color:#FF1493; color:#000000; padding:4px; border-radius:5px;"> 5-2. 변수 유의성 평가 </span>

# %% [markdown]
# > ##### t 검정
# - 독립 변수의 회귀계수가 유의미한지 검정하는데 사용
# - 귀무가설(H0): 회귀계수(a) = 0 => 독립변수가 종속변수에 영향 X
# - 대립가설(H1): 회귀계수(a) ≠ 0 => 독립변수가 족속변수에 영향 O

# %% [markdown]
# > ##### t-값 계산
# - $t = \frac{\hat{\beta} - 0}{SE(\hat{\beta})}$,
# - $\hat{\beta}$: 추정된 회귀계수
# - ${SE(\hat{\beta})}$: 표준오차

# %% [markdown]
# > ##### p-value 확인 및 판단
# - p-value < 0.05: 귀무가설 기각 => 해당 변수 유의미
# - p-value >= 0.05: 귀무가설 기각X => 해당 변수 유의미 X

# %% [markdown]
# > ##### 해석
# - 회귀계수 = 0: 해당 독립변수 의미 X
# - p-value⬇️ => 해당 변수가 종속변수에 더 큰 영향을 줄 확률⬆️
# - t-값이 크면 귀무가설을 기각할 가능성⬆️
