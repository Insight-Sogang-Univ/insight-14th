# %% [markdown]
# # <span style="color:black; background-color:#F5F5F5;">  **SESSION08_데이터로 보는 비지니스 상황🕴🏻** </span>

# %% [markdown]
# - Data-Driven Decision Making
# - 6 Steps of DDDM
# - 데이터 분석 유형
# - 지표

# %% [markdown]
# ## **1. 데이터 기반 의사결정**

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;">1-1. Data-Driven-Decision-Making (DDDM) </span>
#
# `: 비지니스 의사 결정을 제공하기 위해 직관 대신 데이터와 분석을 사용하는 것 강조하는 접근 방식`
#
# ![image.png](attachment:image.png)
# - 고객 피드백, 시장 동향 및 재무 데이터와 같은 데이터 소스 활용 => 의사 결정 프로세스 안내하는 것
# - 데이터 수집, 분석 및 해석 => 조직: 비지니스 목표 및 목적에 더욱 밀집하게 부합하는 더 나은 의사 결정

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;">1-2. 6 Steps of DDDM </span>
# ![image.png](attachment:image.png)
# **1. 목표 정의**: 조직의 목표 명확히 표현
#
# **2. 데이터 식별, 준비 및 수집**: 조직은 데이터 요구 사항 판별 => 데이터 소스 평가 및 준비 => 체계적으로 수집 및 검증
#
# **3. 구성 및 탐색:** 새로운 패턴, 추세 및 가치 있는 인사이트를 발견 할 수 있도록 데이터 구조화
#
# **4. 데이터 분석 수행**: 다양한 기술, 방법론 => 원시 데이터를 실행 가능한 인사이트로 변환 => 비지니스 전략에 영향을 미치는 패턴, 상관관계 및 추세 파악
#
# **5. 결론 도출**: 주요 데이터 분석 결과 검토, 올바른 비지니스 상황에 배치 => 실행 가능한 인사이트와 권장 사항 구성
#
# **6. 구현 및 평가**: 데이터 기반 권장 사항 기반 실행 계획 개발, 리소스 할당 => 이니셔티브의 진행 상황 지속적 모니터링

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;"> 1-3. 데이터 분석 유형 </span>
# ![image.png](attachment:image.png)
# **1. 설명 분석**: 데이터 취합 및 마이닝 => 과거 데이터 설명, 요약 => 과거 성과에 대한 인사이트 제공
#
# **2. 진단 분석**: 특정 이벤트가 발생한 이유 파악
#
# **3. 예측 분석**: 과거 데이터 기반 => 미래의 추세, 결과 예측
#
# **4. 처방 분석**: 데이터 기반 => 조치 권장

# %% [markdown]
# ## **2. 목표 정의**

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;"> 2-1. 지표 </span>
# `방향이나 목적, 기준 따위를 나타내는 표지 / 지수, 척도 등 / 측정하고 싶은 것을 숫자로 표현한 것`
#
# ## $\text{metrics} = \frac{\text{molecule}}{\text{denominator}}$
# | 유형 | 공식 구조 | 예시 지표 |
# |-----|---------|---------|
# | 효율성 | 산술/투입 | 노동 생산성 = 생산량/노동시간 |
# | 효과성 | 달성 결과/목표 | 목표 달성률 = 실제 매출/목표 매출|
# | 수익성 | 이익/자원| ROE = 순수익/자기자본 |
# | 성장성 | 증가분/기존 규모 |  매출 성장률 = (당기매출-전기매출)/전기매출 |
# | 안정성 | 보유자산/부채 | 부채비율 = 부채/자기자본 |

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;"> 2-2. 지표 정의하기 </span>
# > ### Proxy Metric
# `활성화와 인게이지 같이 추상적이여서 프로덕트마다 나름의 가정, 정의, 논의가 필요한 지표`
# - 설정 자체에 많은 논의 필요
# - 정답 존재 X

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;"> 2-3. 북극성 지표 L1/L2 Metrics </span>
# `기업이 가장 중요하게 생각하는 지표 (ex: 에어비앤비 - 예약된 박 수, 페이스북 - DAU)`
# - **L1**: 전사적인, 고수준의 성과 지표 (전략 관점)
# - **L2**: L1 지표의 세부 사항 측정 (전술 관점)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <span style="color:black; background-color:#FFF099;"> 2-4. AARRR </span>
# > 넷플릭스, 유튜브, 스포티파이
# - 중요한 지표: 컨텐츠 감상 시간
# - 감상 시간⬆️ => 광고 수익, 유저 리텐션 등에 좋은 영향
# > 우버
# - 공급자, 수요자 매칭 서비스
# - 택시를 부르는 사람들의 요청 중 몇 퍼센트가 실제 매칭되는지 중요
# ![image.png](attachment:image.png)
#
# **1. Acquisition**: 사용자 획득, 사용자가 여러 채널을 통해 앱 or 웹사이트에 방문하는 것
# `- CAC (Customer Acquisition Cost): 유저 획득 비용`
# `- CTR (Cost Per Click): 클릭 한 건당 얼마 지출`
# `- CPC (Cost Per Install): 인스톨 당 과금되는 상품`
# `- CPL (Cost Per Lead): 유저 행동 당 드는 비용`
# `- ROAS (Return On Ads Spending): 광고로 인한 매출액/광고비`
#
# **2. Activation**: 사용자 활성화, 사용자가 앱 or 웹사이트에 첫 방문하여 주요 기능을 직접 사용하는 것
# `- Sign-up: 유저가 제품에 들어온 시점`
# `- Setup Moment: 유저가 제품의 핵심가치를 경험할 준비 완료`
# `- A-HA! Moment: 유저가 핵심가치를 처음 경험한 순간`
# `- Habit Moment: 유저가 제품 사용에 대한 습관 형성`
#
# **3. Retention**: 유지 단계에서 신규 사용자 -> 장기 사용자로 전환시키는 것 초점
# `- DN Retention: N일 안으로 재접속하는 경우`
# `- MAU/DAU/WAU: 일/주/월마다 방문하는 횟수`
# `- Stickness(DAU, MAU): 해당기간 동안 활성화 수`
#
# **4. Revenue**: 수익 단계에서 사용자가 제품 or 서비스를 유료 구매하기로 결정
# `- PU(Paying User): 전체 사용자 중에 결제를 한 사용자 비율`
# `- Average Check: 구매 1회당 평균 금액 (Revenue/Transaction)`
# `- ARPU(Average Revenue Per User): 인당 평균 매출`
# `- ARPPU(Average Revenue Per Paying User): 결제자당 평균 매출`
# `- LTV(Life Time Value): 유저가 진입부터 이탈까지 누적 수익`
#
# **5. Referral**: 사용자가 만족했다면 타인에게 추천
# `- 바이럴 계수: 기존 고객 한명당 데리고 온 새로운 고객의 수`
# `- 바이럴 주기: 기존 고객 1명이 새로운 고객을 데려오는데 걸리는 시간`
